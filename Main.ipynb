# %%
#coding: UTF-8
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import time
import os
os.chdir('C:\\Users\LAB401\FGD')
#os.chdir('D:\FGD') 
print (os.getcwd())
import glob
list = glob.glob('D:\FGD\data\**\*.txt',recursive=True)
for i,j in enumerate(list):
    print(i,j)
    path_data = j
    # %store path_data > temp_path.txt
    del path_data # This has deleted the variable
    filename = "C:\\Users\LAB401\FGD\solar-term-circulatory.py"
    # %run $filename
# Out:
# C:\Users\LAB401\FGD
# 0 D:\FGD\data\PM25.txt
# Writing 'path_data' (str) to file 'temp_path.txt'.
# sD:\FGD\pics\PM25
# D:\anaconda\1\lib\site-packages\matplotlib\__init__.py:938: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# D:\anaconda\1\lib\site-packages\matplotlib\font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# D:\anaconda\1\lib\site-packages\matplotlib\font_manager.py:1297: UserWarning: findfont: Font family ['helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# D:\anaconda\1\lib\site-packages\matplotlib\font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# ...

# %%
ssss = 'PM2.5.txt'
print(ssss.split('\\')[-1].split('.')[-2])
print(ssss[:-4])
#inputdataname.split('\\')[-1].split('.')[-2]
# Out:
# 5
# PM2.5
